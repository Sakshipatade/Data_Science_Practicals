# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\91911\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\91911\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\91911\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
dataset =  pd.read_csv("Facebook Metrics of Cosmetic Brand.csv")
dataset
# Out:
#      Unnamed: 0  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0             0            139441   Photo         2          12             4
# 1             1            139441  Status         2          12             3
# 2             2            139441   Photo         3          12             3
# 3             3            139441   Photo         2          12             2
# 4             4            139441   Photo         2          12             2
# ..          ...               ...     ...       ...         ...           ...
# 495         495             85093   Photo         3           1             7
# 496         496             81370   Photo         2           1             5
# 497         497             81370   Photo         1           1             5
# 498         498             81370   Photo         3           1             4
# 499         499             81370   Photo         2           1             4
#
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0           0            139441   Photo         2          12             4
# 1           1            139441  Status         2          12             3
# 2           2            139441   Photo         3          12             3
# 3           3            139441   Photo         2          12             2
# 4           4            139441   Photo         2          12             2
#
#    Post Hour  Paid  Lifetime Post Total Reach  \
# 0          3   0.0                       2752
# 1         10   0.0                      10460
# 2          3   0.0                       2413
# 3         10   1.0                      50128
# 4          3   0.0                       7244
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# ...

# %%
dataset_subset1=dataset[["Type","Category"]]
dataset_subset1
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
dataset_subset2=dataset[["Post Month","Paid"]]
dataset_subset2
# Out:
#      Post Month  Paid
# 0            12   0.0
# 1            12   0.0
# 2            12   0.0
# 3            12   1.0
# 4            12   0.0
# ..          ...   ...
# 495           1   0.0
# 496           1   0.0
# 497           1   0.0
# 498           1   0.0
# 499           1   NaN
#
# [500 rows x 2 columns]

# %%
dataset_merge=pd.concat([dataset_subset1, dataset_subset2])
dataset_merge
# Out:
#        Type  Category  Post Month  Paid
# 0     Photo       2.0         NaN   NaN
# 1    Status       2.0         NaN   NaN
# 2     Photo       3.0         NaN   NaN
# 3     Photo       2.0         NaN   NaN
# 4     Photo       2.0         NaN   NaN
# ..      ...       ...         ...   ...
# 495     NaN       NaN         1.0   0.0
# 496     NaN       NaN         1.0   0.0
# 497     NaN       NaN         1.0   0.0
# 498     NaN       NaN         1.0   0.0
# 499     NaN       NaN         1.0   NaN
#
# [1000 rows x 4 columns]

# %%
dataset_merge.tail()
# Out:
#     Type  Category  Post Month  Paid
# 495  NaN       NaN         1.0   0.0
# 496  NaN       NaN         1.0   0.0
# 497  NaN       NaN         1.0   0.0
# 498  NaN       NaN         1.0   0.0
# 499  NaN       NaN         1.0   NaN

# %%
dataset_sort = dataset_merge.sort_values(by="Post Month", ascending=False)

dataset_sort
# Out:
#       Type  Category  Post Month  Paid
# 21     NaN       NaN        12.0   0.0
# 22     NaN       NaN        12.0   0.0
# 23     NaN       NaN        12.0   0.0
# 24     NaN       NaN        12.0   0.0
# 25     NaN       NaN        12.0   0.0
# ..     ...       ...         ...   ...
# 495  Photo       3.0         NaN   NaN
# 496  Photo       2.0         NaN   NaN
# 497  Photo       1.0         NaN   NaN
# 498  Photo       3.0         NaN   NaN
# 499  Photo       2.0         NaN   NaN
#
# [1000 rows x 4 columns]

# %%
dataset.transpose()
# Out:
#                                                        0       1       2    \
# Unnamed: 0                                               0       1       2
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# ...

# %%
transposed_data=dataset.transpose()
transposed_data
# Out:
#                                                        0       1       2    \
# Unnamed: 0                                               0       1       2
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# ...

# %%
new_data=transposed_data.transpose()
new_data
# Out:
#     Unnamed: 0 Page total likes    Type Category Post Month Post Weekday  \
# 0            0           139441   Photo        2         12            4
# 1            1           139441  Status        2         12            3
# 2            2           139441   Photo        3         12            3
# 3            3           139441   Photo        2         12            2
# 4            4           139441   Photo        2         12            2
# ..         ...              ...     ...      ...        ...          ...
# 495        495            85093   Photo        3          1            7
# 496        496            81370   Photo        2          1            5
# 497        497            81370   Photo        1          1            5
# 498        498            81370   Photo        3          1            4
# 499        499            81370   Photo        2          1            4
#
#     Post Hour Paid Lifetime Post Total Reach Lifetime Post Total Impressions  \
# ...

# %%
dataset.shape
# Out:
# (500, 20)

# %%
import numpy as np

# %%
arr=np.array(["comment", "like", "Type1","Type2"])

# %%
arr
# Out:
# array(['comment', 'like', 'Type1', 'Type2'], dtype='<U7')

# %%
new =arr.reshape(2,2)
new
# Out:
# array([['comment', 'like'],
#        ['Type1', 'Type2']], dtype='<U7')
